# %% [markdown]
# # Creating DataFrame

# %% [markdown]
# ### Creating

# %%
import numpy as np
import pandas as pd

# Using Numpy
dataOne = np.array([["Emon",242001322],["Upal",46574654],["Irfan",737654]]) # Creating an 2D array
dfOne = pd.DataFrame(dataOne, columns = ["Name", "Roll"])
print("\n")
print(dfOne)
print("\n")

# Using Dictionary
names = []
roll = []
i = 0
while i<=1:
    inp = input(f"Enter {i} name:")
    names.append(inp)
    inp = input(f"Enter {i} roll:")
    roll.append(inp)
    i += 1
dataTwo = {"Name":names,"Roll":roll}
dfTwo = pd.DataFrame(dataTwo)
print("\n")
print(dfTwo)
print("\n")

# Reading CSV
dfThree = pd.read_csv("dummy.csv")
print(dfThree.head()) # Returns first 5 rows
print("\n")
dfThree # It returns a summary with first and last 5 rows.
# Out:
#     Name       Roll
# 0   Emon  242001322
# 1   Upal   46574654
# 2  Irfan     737654
# Enter 0 name: Emon
# Enter 0 roll: 242001322
# Enter 1 name: Upal
# Enter 1 roll: 242001355
#    Name       Roll
# 0  Emon  242001322
# 1  Upal  242001355
#
#
#       Name  Roll  Zip Code
# 0     Emon     1      7894
# 1     Upal     2      4577
# 2    Jasim     3      1123
# 3  Urbashi     4      1457
# 4        A     5      1791
#          Name  Roll  Zip Code
# 0        Emon     1      7894
# 1        Upal     2      4577
# 2       Jasim     3      1123
# 3     Urbashi     4      1457
# 4           A     5      1791
# 5           B     6      2125
# 6           C     7      2459
# 7           A     8      2793
# 8           B     9      3127
# 9           C    10      3461
# 10          A    11      3795
# 11          B    12      4129
# 12          C    13      4463
# 13          A    14      4797
# 14          B    15      5131
# 15          C    16      5465
# 16          A    17      5799
# ...

# %% [markdown]
# ### Displaying

# %%
dfThree.head(7) # It returns first 7 rows
# Out:
#       Name  Roll  Zip Code
# 0     Emon     1      7894
# 1     Upal     2      4577
# 2    Jasim     3      1123
# 3  Urbashi     4      1457
# 4        A     5      1791
# 5        B     6      2125
# 6        C     7      2459

# %%
dfThree.tail(7) # It returns last 7 rows
# Out:
#          Name  Roll  Zip Code
# 1672        A  1673    558903
# 1673        B  1674    559237
# 1674        C  1675    559571
# 1675     Emon  1676    559905
# 1676     Upal  1677    560239
# 1677    Jasim  1678    560573
# 1678  Urbashi  1679    560907

# %%
rowColumnNum = dfThree.shape # It returns row and column number of our data frame as tuple (set).
rowNum = rowColumnNum[0]
columnNum = rowColumnNum[1]
pd.set_option("display.max_rows", rowNum) # Now we will be able to print the full data frame with all rows.
dfThree # full data frame with all rows.
# Out:
#          Name  Roll  Zip Code
# 0        Emon     1      7894
# 1        Upal     2      4577
# 2       Jasim     3      1123
# 3     Urbashi     4      1457
# 4           A     5      1791
# 5           B     6      2125
# 6           C     7      2459
# 7           A     8      2793
# 8           B     9      3127
# 9           C    10      3461
# 10          A    11      3795
# 11          B    12      4129
# 12          C    13      4463
# 13          A    14      4797
# 14          B    15      5131
# 15          C    16      5465
# 16          A    17      5799
# 17          B    18      6133
# 18          C    19      6467
# 19          A    20      6801
# 20          B    21      7135
# 21          C    22      7469
# 22          A    23      7803
# 23          B    24      8137
# 24          C    25      8471
# 25       Emon    26      8805
# 26       Upal    27      9139
# 27      Jasim    28      9473
# 28    Urbashi    29      9807
# 29          A    30     10141
# ...
