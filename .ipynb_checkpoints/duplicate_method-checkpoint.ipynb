# %% [markdown]
# # Using duplicated() method to find out column values is unique or not

# %%
import pandas as pd

# %%
dfCmt = pd.read_csv("laptop_price.csv", encoding = "unicode_escape")
dfCmt
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
dfCmt[~dfCmt.duplicated("laptop_ID")].value_counts("laptop_ID") # '~' means not in pandas
# Out:
# laptop_ID
# 1       1
# 867     1
# 885     1
# 884     1
# 883     1
#        ..
# 440     1
# 439     1
# 438     1
# 437     1
# 1320    1
# Name: count, Length: 1303, dtype: int64

# %%
dfCmt.set_index("laptop_ID", inplace = True) # So a non duplicate field can be index.
dfCmt
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %% [markdown]
# # Finding duplicates from multiple columns

# %%
dfCmt[dfCmt.duplicated(["Memory", "Cpu"])].sort_values(["Cpu","Memory"])
# Out:
#           Company                               Product  TypeName  Inches  \
# laptop_ID
# 1258       Lenovo                     IdeaPad 320-15ABR  Notebook    15.6
# 1123           HP  15-bw011nv (A6-9220/4GB/1TB/FHD/W10)  Notebook    15.6
# 147            HP                                255 G6  Notebook    15.6
# 1269           HP                                255 G6  Notebook    15.6
# 1298           HP                   Pavilion 15-AW003nv  Notebook    15.6
# ...           ...                                   ...       ...     ...
# 867          Asus            X541NA (N4200/4GB/1TB/W10)  Notebook    15.6
# 887          Asus    X541NA-GO121 (N4200/4GB/1TB/Linux)  Notebook    15.6
# 944        Lenovo                     IdeaPad 320-15IAP  Notebook    15.6
# 575        Lenovo                     IdeaPad 320-15IAP  Notebook    15.6
# 1011         Acer                        Aspire ES1-533  Notebook    15.6
#
# ...

# %%
dfCmt[~dfCmt.duplicated(["Memory", "Cpu"])].sort_values(["Cpu","Memory"]) # '~' means not in pandas
# Out:
#            Company                                 Product  \
# laptop_ID
# 303         Lenovo                       IdeaPad 310-15ABR
# 696             HP     17-Y002nv (A10-9600P/6GB/2TB/Radeon
# 500           Acer                                Aspire 5
# 717             HP    17-ak002nv (A10-9620P/6GB/2TB/Radeon
# 565             HP  15-bw007nv (A10-9620P/6GB/128GB/Radeon
# ...            ...                                     ...
# 208           Dell                          Precision 7520
# 454           Dell                          Precision 3520
# 758             HP                                Zbook 17
# 617         Lenovo                            Thinkpad P51
# 1209       Samsung                         Chromebook Plus
#
#                      TypeName  Inches                 ScreenResolution  \
# laptop_ID
# 303                  Notebook    15.6                Full HD 1920x1080
# 696                  Notebook    17.3      IPS Panel Full HD 1920x1080
# ...

# %% [markdown]
# # Most & Least expansive from each company

# %%
dfCmt.sort_values("Price_euros", inplace = True)
dfCmt
# Out:
#           Company                               Product     TypeName  Inches  \
# laptop_ID
# 1233         Acer      C740-C9QX (3205U/2GB/32GB/Chrome      Netbook    11.6
# 21           Asus                       Vivobook E200HA      Netbook    11.6
# 1135         Vero      V131 (X5-Z8350/4GB/32GB/FHD/W10)     Notebook    13.3
# 32           Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)     Notebook    14.0
# 295          Acer                  Chromebook C910-C2ST     Notebook    15.6
# ...           ...                                   ...          ...     ...
# 1081         Asus                            ROG G701VO       Gaming    17.3
# 758            HP                              Zbook 17  Workstation    17.3
# 617        Lenovo                          Thinkpad P51     Notebook    15.6
# 839         Razer                             Blade Pro       Gaming    17.3
# 200         Razer                             Blade Pro       Gaming    17.3
#
# ...

# %%
dfLep = dfCmt.duplicated("Company", keep = "first") # If we set keep "first"
dfLep = dfCmt[~dfLep]
dfLep # Least Expensive Product (LEP) from each company.
# Out:
#              Company                           Product   TypeName  Inches  \
# laptop_ID
# 1233            Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 21              Asus                   Vivobook E200HA    Netbook    11.6
# 1135            Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook    13.3
# 1300              HP                  Stream 11-Y000na    Netbook    11.6
# 1290          Lenovo                IdeaPad 100S-14IBR   Notebook    14.0
# 633         Mediacom                     SmartBook 140   Notebook    14.0
# 31             Chuwi                     LapBook 15.6"   Notebook    15.6
# 437          Samsung                      Chromebook 3    Netbook    11.6
# 346             Dell                     Inspiron 3552   Notebook    15.6
# 163          Toshiba                     Satellite Pro   Notebook    15.6
# 997          Fujitsu                     LifeBook A556   Notebook    15.6
# ...

# %%
dfMep = dfCmt[~dfCmt.duplicated("Company", keep = "last")] # If we set keep "last"
dfMep # Most Expensive Product (MEP) from each company.
# Out:
#              Company                        Product     TypeName  Inches  \
# laptop_ID
# 195             Vero  K147 (N3350/4GB/32GB/FHD/W10)     Notebook    14.0
# 587         Mediacom                 SmartBook Edge     Notebook    14.0
# 428            Chuwi                   LapBook 12.3     Notebook    12.3
# 630          Fujitsu                  LifeBook A557     Notebook    15.6
# 521           Xiaomi                    Mi Notebook     Notebook    15.6
# 219           Huawei                     MateBook X    Ultrabook    13.0
# 885          Samsung                     Notebook 9    Ultrabook    15.0
# 444           Google                Pixelbook (Core    Ultrabook    12.3
# 686               LG                    Gram 15Z975    Ultrabook    15.6
# 456        Microsoft                 Surface Laptop    Ultrabook    13.5
# 1207            Acer                Predator G9-793       Gaming    17.3
# 181              MSI                GT80S 6QF-074US       Gaming    18.4
# ...

# %%
dfCmt[~dfCmt.duplicated("Company", keep = False)] # If we set keep False
# Out:
# Empty DataFrame
# Columns: [Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros]
# Index: []
