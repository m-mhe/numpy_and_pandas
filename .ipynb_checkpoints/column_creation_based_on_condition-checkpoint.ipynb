# %% [markdown]
# # Create a column based on one condition uasing np.where():

# %%
import pandas as pd
import numpy as np
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
dfLaptops = pd.read_csv("laptop_price.csv", encoding = "unicode_escape")
dfLaptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
np.where(dfLaptops["Inches"]>15) # Returns index where screen size is bigger than 15 inches.
# Out:
# (array([   2,    3,    5,    6,   10,   11,   12,   13,   16,   17,   18,
#           21,   22,   24,   25,   27,   28,   29,   30,   32,   36,   37,
#           38,   39,   40,   41,   42,   43,   44,   46,   47,   48,   49,
#           51,   52,   54,   55,   56,   57,   58,   59,   60,   64,   65,
#           66,   68,   69,   72,   73,   75,   76,   77,   78,   79,   80,
#           83,   84,   85,   86,   87,   88,   90,   91,   93,   96,   97,
#           98,   99,  100,  101,  102,  106,  108,  110,  117,  118,  119,
#          120,  121,  122,  123,  124,  125,  128,  129,  130,  131,  133,
#          134,  136,  137,  138,  140,  142,  143,  144,  147,  148,  149,
#          150,  151,  152,  153,  155,  158,  159,  160,  161,  162,  163,
#          164,  165,  166,  167,  168,  171,  172,  173,  174,  175,  176,
#          177,  178,  180,  183,  184,  185,  186,  187,  189,  193,  195,
#          196,  198,  199,  200,  201,  202,  203,  204,  205,  206,  209,
# ...

# %%
np.where(dfLaptops["Inches"]>=15, "Big Screen", "Small Screen") # Returns an array based on screen size.
# Out:
# array(['Small Screen', 'Small Screen', 'Big Screen', ..., 'Small Screen',
#        'Big Screen', 'Big Screen'], dtype='<U12')

# %%
dfLaptops = dfLaptops.assign(Display = np.where(dfLaptops["Inches"]>=15, "Big Screen", "Small Screen")) # Creating a column based on one condition uasing np.where():
dfLaptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
dfLaptops["Display"].value_counts()
# Out:
# Display
# Big Screen      839
# Small Screen    464
# Name: count, dtype: int64
